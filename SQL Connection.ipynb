# %%
import pandas as pd
import mysql.connector

# %%
df = pd.read_csv("E:/\practice data sets/Mental Health/mental_health_dataset.csv")

# %%
df.head(10)
# Out:
#    age      gender employment_status work_environment mental_health_history  \
# 0   56        Male          Employed          On-site                   Yes
# 1   46      Female           Student          On-site                    No
# 2   32      Female          Employed          On-site                   Yes
# 3   60  Non-binary     Self-employed          On-site                    No
# 4   25      Female     Self-employed          On-site                   Yes
# 5   38      Female        Unemployed          On-site                   Yes
# 6   56  Non-binary          Employed           Remote                    No
# 7   36        Male           Student           Remote                    No
# 8   40        Male          Employed           Hybrid                    No
# 9   28      Female          Employed           Remote                    No
#
#   seeks_treatment  stress_level  sleep_hours  physical_activity_days  \
# ...

# %%
con = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='sri123',
    database='mental_health'
    
)

cursor = con.cursor()
print(con)

# %%
for _,row in df.iterrows():
    cursor.execute(""" 
    INSERT INTO employee_mental_health(`age`, `gender`, `employment_status`, `work_environment`, `mental_health_history`, `seeks_treatment`, 
    `stress_level`, `sleep_hours`, `physical_activity_days`, `depression_score`, `anxiety_score`, `social_support_score`, `productivity_score`,
    `mental_health_risk`)
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
    """,tuple(row))

print(df.head())
# Out:
#    age      gender employment_status work_environment mental_health_history  \
# 0   56        Male          Employed          On-site                   Yes
# 1   46      Female           Student          On-site                    No
# 2   32      Female          Employed          On-site                   Yes
# 3   60  Non-binary     Self-employed          On-site                    No
# 4   25      Female     Self-employed          On-site                   Yes
#
#   seeks_treatment  stress_level  sleep_hours  physical_activity_days  \
# 0             Yes             6          6.2                       3
# 1             Yes            10          9.0                       4
# 2              No             7          7.7                       2
# 3              No             4          4.5                       4
# 4             Yes             3          5.4                       0
#
#    depression_score  anxiety_score  social_support_score  productivity_score  \
# ...

# %%
con.commit()

# %%
con.close()
